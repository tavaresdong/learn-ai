# %%
from keras.datasets import imdb
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\users\yucdong\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\pywrap_tensorflow.py in swig_import_helper()
#      17         try:
# ---> 18             fp, pathname, description = imp.find_module('_pywrap_tensorflow', [dirname(__file__)])
#      19         except ImportError:
#
# c:\users\yucdong\appdata\local\programs\python\python37\lib\imp.py in find_module(name, path)
#     296     else:
# --> 297         raise ImportError(_ERR_MSG.format(name), name=name)
#     298
#
# ImportError: No module named '_pywrap_tensorflow'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# ...
